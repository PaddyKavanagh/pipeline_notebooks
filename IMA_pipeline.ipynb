# %% [markdown]
# # Run level 2A, 2B and 3 pipelines on Imager data using jwst.pipeline classes

# %% [markdown]
# ### by Patrick Kavanagh (DIAS, Ireland) January 9th 2017

# %% [markdown]
# This notebook demonstrates the execution of the level 2A, 2B and 3 pipelines for Imager data in Python using the jwst.pipeline classes.
#
# For a description of the pipeline classes see:
#
# http://ssb.stsci.edu/doc/jwst_git/docs/pipeline/html/description.html
#
# The file used in this notebook is a MIRISim simulation of a field with 500 point sources and 10 galaxies randomly distributed.

# %% [markdown]
# #### Imports

# %%
import os, glob

import numpy as np
from astropy.io import fits

import matplotlib.pyplot as plt

# %% [markdown]
# #### Set input file:

# %%
# set filename
input_file = 'det_image_1_MIRIMAGE_F1130Wexp1.fits'

# extract the basename for use in output files
input_basename = os.path.splitext(input_file)[0]

# %% [markdown]
# #### print some information about the input file

# %%
# print some info on input file
with fits.open(input_file) as hdulist:
    
    if hdulist[0].header['ORIGIN'] == 'STScI':
        # specific information on instrument/exposure
        identifier = hdulist[0].header['OBS_ID']
        detector = hdulist[0].header['DETECTOR']
        im_filter = hdulist[0].header['FILTER']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print "ID\t\t\t Detector\t Filter\t subAr\t nInts\t nGrps\t rdPatt\t ExpTime (s)"
        print "--------------------------------------------------------------------------------------------------"
        print "%s\t %s\t %s\t %s\t %d\t %d\t %s\t %0.1f" % (identifier,detector,im_filter,subArr,nInts,nGroups,readPatt,expTime)
        print "\n\n"
            
    else:
        # specific information on instrument/exposure
        detector = hdulist[0].header['DETECTOR']
        im_filter = hdulist[0].header['FILTER']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        print "ID\t Detector\t Filter\t subAr\t nInts\t nGrps\t rdPatt\t ExpTime (s)"
        print "--------------------------------------------------------------------------------------------------"
        print "MIRISim\t %s\t %s\t %s\t %d\t %d\t %s\t %0.1f" % (detector,im_filter,subArr, nInts,nGroups,readPatt,expTime)
        print "\n\n"

    # fits extension table
    hdulist.info()
# Out:
# ID	 Detector	 Filter	 subAr	 nInts	 nGrps	 rdPatt	 ExpTime (s)
# --------------------------------------------------------------------------------------------------
# MIRISim	 MIRIMAGE	 F1130W	 FULL	 3	 20	 FAST	 166.5
#
#
#
# Filename: det_image_1_MIRIMAGE_F1130Wexp1.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     136   ()
#   1  SCI         ImageHDU        14   (1032, 1024, 20, 3)   float32
#   2  REFOUT      ImageHDU        14   (258, 1024, 20, 3)   float32
#   3  PIXELDQ     ImageHDU        10   (1032, 1024)   int32 (rescales to uint32)
#   4  PIXELDQ_DEF  BinTableHDU     17   29R x 4C   [J, J, 40A, 128A]
#   5  ASDF        ImageHDU         7   (322324727,)   uint8

# %% [markdown]
# #### show the last frame of the first integration

# %%
from jwst import datamodels
from matplotlib.colors import LogNorm

# open the input image as a jwst data model
with datamodels.open(input_file) as in_dm:
        
    # plot--------------------------------------
    # show the input ramp image. Note the user 
    # may need to adjust the scale parameters
    # of the plot
    # %matplotlib notebook
    fig, axs = plt.subplots(1, 1, figsize=(8, 8))

    # sum the groups in the first integration of the input ramp image and plot
    axs.imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1.0e4,vmax=1.3e4))
    axs.annotate('Input ramp image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs.set_axis_bgcolor('black')

    plt.tight_layout()
    plt.show()
# Out:
# No handlers could be found for logger "jwst.datamodels.util"
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Level 2A pipeline (ramps-to-slopes)

# %% [markdown]
# #### import the level 2A pipeline class and print description

# %%
from jwst.pipeline import SloperPipeline
print SloperPipeline.__doc__
# Out:
# The following task in the fitsblender package can be run with TEAL:
#                                   blendheaders
#
#
#     SloperPipeline: Apply all calibration steps to raw JWST
#     ramps to produce a 2-D slope product. Included steps are:
#     dq_init, saturation, ipc, superbias, refpix, rscd, lastframe,
#     linearity, dark_current, persistence, jump detection, and ramp_fit.

# %% [markdown]
# For MIRI, the steps in order are: dq_init, saturation, ipc, linearity, RSCD, lastframe, dark_current, refpix, persistence (no-op), jump, ramp_fitting

# %% [markdown]
# #### run pipeline

# %%
SloperPipeline.call(input_file, output_file='%s_rate.fits' % input_basename)
# Out:
# 2017-02-16 16:43:28,852 - stpipe.SloperPipeline - INFO - SloperPipeline instance created.
# 2017-02-16 16:43:28,853 - stpipe.SloperPipeline.ipc - INFO - IPCStep instance created.
# 2017-02-16 16:43:28,855 - stpipe.SloperPipeline.saturation - INFO - SaturationStep instance created.
# 2017-02-16 16:43:28,857 - stpipe.SloperPipeline.rscd - INFO - RSCD_Step instance created.
# 2017-02-16 16:43:28,859 - stpipe.SloperPipeline.ramp_fit - INFO - RampFitStep instance created.
# 2017-02-16 16:43:28,860 - stpipe.SloperPipeline.linearity - INFO - LinearityStep instance created.
# 2017-02-16 16:43:28,863 - stpipe.SloperPipeline.jump - INFO - JumpStep instance created.
# 2017-02-16 16:43:28,864 - stpipe.SloperPipeline.refpix - INFO - RefPixStep instance created.
# 2017-02-16 16:43:28,866 - stpipe.SloperPipeline.lastframe - INFO - LastFrameStep instance created.
# 2017-02-16 16:43:28,867 - stpipe.SloperPipeline.dq_init - INFO - DQInitStep instance created.
# 2017-02-16 16:43:28,869 - stpipe.SloperPipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2017-02-16 16:43:28,870 - stpipe.SloperPipeline.persistence - INFO - PersistenceStep instance created.
# 2017-02-16 16:43:28,871 - stpipe.SloperPipeline.superbias - INFO - SuperBiasStep instance created.
# 2017-02-16 16:43:38,016 - stpipe.SloperPipeline.ipc - INFO - Prefetch for IPC reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0009.fits'.
# 2017-02-16 16:43:42,037 - stpipe.SloperPipeline.saturation - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits'.
# 2017-02-16 16:43:46,291 - stpipe.SloperPipeline.rscd - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits'.
# 2017-02-16 16:43:50,480 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2017-02-16 16:43:50,481 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits'.
# 2017-02-16 16:43:54,570 - stpipe.SloperPipeline.linearity - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0014.fits'.
# 2017-02-16 16:43:58,380 - stpipe.SloperPipeline.jump - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2017-02-16 16:43:58,381 - stpipe.SloperPipeline.jump - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits'.
# 2017-02-16 16:44:02,149 - stpipe.SloperPipeline.refpix - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2017-02-16 16:44:08,233 - stpipe.SloperPipeline.dq_init - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits'.
# 2017-02-16 16:44:12,236 - stpipe.SloperPipeline.dark_current - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0058.fits'.
# 2017-02-16 16:44:18,228 - stpipe.SloperPipeline.superbias - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2017-02-16 16:44:18,499 - stpipe.SloperPipeline - INFO - Step SloperPipeline running with args ('det_image_1_MIRIMAGE_F1130Wexp1.fits',).
# 2017-02-16 16:44:18,500 - stpipe.SloperPipeline - INFO - Starting calwebb_sloper ...
# 2017-02-16 16:44:20,878 - stpipe.SloperPipeline.dq_init - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits'.
# 2017-02-16 16:44:21,018 - stpipe.SloperPipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1b48a8dd0>,).
# 2017-02-16 16:44:22,506 - stpipe.SloperPipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits
# 2017-02-16 16:44:23,210 - stpipe.SloperPipeline.dq_init - INFO - Step dq_init done
# 2017-02-16 16:44:24,764 - stpipe.SloperPipeline.saturation - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits'.
# 2017-02-16 16:44:24,899 - stpipe.SloperPipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x11290c450>,).
# 2017-02-16 16:44:26,543 - stpipe.SloperPipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits
# 2017-02-16 16:44:27,852 - stpipe.SloperPipeline.saturation - INFO - Step saturation done
# 2017-02-16 16:44:29,448 - stpipe.SloperPipeline.ipc - INFO - Prefetch for IPC reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0009.fits'.
# 2017-02-16 16:44:29,592 - stpipe.SloperPipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1b4886610>,).
# 2017-02-16 16:44:31,060 - stpipe.SloperPipeline.ipc - INFO - Using IPC reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0009.fits
# 2017-02-16 16:44:33,607 - stpipe.SloperPipeline.ipc - INFO - Step ipc done
# 2017-02-16 16:44:35,173 - stpipe.SloperPipeline.linearity - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0014.fits'.
# 2017-02-16 16:44:35,304 - stpipe.SloperPipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x112955cd0>,).
# 2017-02-16 16:44:36,763 - stpipe.SloperPipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0014.fits
# 2017-02-16 16:44:38,364 - stpipe.SloperPipeline.linearity - INFO - Step linearity done
# 2017-02-16 16:44:39,915 - stpipe.SloperPipeline.rscd - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits'.
# 2017-02-16 16:44:40,045 - stpipe.SloperPipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1b488f7d0>,).
# 2017-02-16 16:44:41,529 - stpipe.SloperPipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits
# 2017-02-16 16:45:58,810 - stpipe.SloperPipeline.rscd - INFO - Step rscd done
# 2017-02-16 16:45:59,128 - stpipe.SloperPipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1b489fc90>,).
# 2017-02-16 16:46:00,269 - stpipe.SloperPipeline.lastframe - INFO - Step lastframe done
# 2017-02-16 16:46:01,764 - stpipe.SloperPipeline.dark_current - INFO - Prefetch for DARK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0058.fits'.
# 2017-02-16 16:46:01,880 - stpipe.SloperPipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1f2349510>,).
# 2017-02-16 16:46:03,327 - stpipe.SloperPipeline.dark_current - INFO - Using DARK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_dark_0058.fits
# 2017-02-16 16:46:03,516 - stpipe.SloperPipeline.dark_current - INFO - Science data nints=3, ngroups=20, nframes=1, groupgap=0
# 2017-02-16 16:46:03,517 - stpipe.SloperPipeline.dark_current - INFO - Dark data nints=2, ngroups=200, nframes=1, groupgap=0
# 2017-02-16 16:46:12,261 - stpipe.SloperPipeline.dark_current - INFO - Step dark_current done
# 2017-02-16 16:46:13,907 - stpipe.SloperPipeline.refpix - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2017-02-16 16:46:14,042 - stpipe.SloperPipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1b4886b90>,).
# 2017-02-16 16:46:14,610 - stpipe.SloperPipeline.refpix - INFO - use_side_ref_pixels = True
# 2017-02-16 16:46:14,611 - stpipe.SloperPipeline.refpix - INFO - odd_even_columns = True
# 2017-02-16 16:46:14,612 - stpipe.SloperPipeline.refpix - INFO - side_smoothing_length = 11
# 2017-02-16 16:46:14,612 - stpipe.SloperPipeline.refpix - INFO - side_gain = 1.000000
# 2017-02-16 16:46:14,613 - stpipe.SloperPipeline.refpix - INFO - odd_even_rows = True
# 2017-02-16 16:46:14,614 - stpipe.SloperPipeline.refpix - INFO - Subtracting initial read from each integration
# 2017-02-16 16:46:15,704 - stpipe.SloperPipeline.refpix - INFO - Adding initial read back in
# 2017-02-16 16:46:17,432 - stpipe.SloperPipeline.refpix - INFO - Step refpix done
# 2017-02-16 16:46:17,832 - stpipe.SloperPipeline.persistence - INFO - Step persistence running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1b489f350>,).
# 2017-02-16 16:46:19,010 - stpipe.SloperPipeline.persistence - WARNING - Persistence step is currently a no-op: SKIPPING
# 2017-02-16 16:46:19,018 - stpipe.SloperPipeline.persistence - INFO - Step persistence done
# 2017-02-16 16:46:20,600 - stpipe.SloperPipeline.jump - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2017-02-16 16:46:20,601 - stpipe.SloperPipeline.jump - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits'.
# 2017-02-16 16:46:20,743 - stpipe.SloperPipeline.jump - INFO - Step jump running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x15fed0d10>,).
# 2017-02-16 16:46:21,285 - stpipe.SloperPipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2017-02-16 16:46:22,201 - stpipe.SloperPipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2017-02-16 16:46:23,100 - stpipe.SloperPipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits
# 2017-02-16 16:46:23,929 - stpipe.SloperPipeline.jump - INFO - Executing two-point difference method
# 2017-02-16 16:46:25,129 - stpipe.SloperPipeline.jump - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7/lib/python2.7/site-packages/numpy/lib/nanfunctions.py:769: RuntimeWarning: All-NaN slice encountered
#   warnings.warn("All-NaN slice encountered", RuntimeWarning)
#
# 2017-02-16 17:04:19,652 - stpipe.SloperPipeline.jump - INFO - Step jump done
# 2017-02-16 17:04:21,216 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2017-02-16 17:04:21,217 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits'.
# 2017-02-16 17:04:21,364 - stpipe.SloperPipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x167ea5790>,).
# 2017-02-16 17:04:23,700 - stpipe.SloperPipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits
# 2017-02-16 17:04:23,786 - stpipe.SloperPipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2017-02-16 17:04:23,868 - stpipe.SloperPipeline.ramp_fit - INFO - Using algorithm = OLS
# 2017-02-16 17:04:23,869 - stpipe.SloperPipeline.ramp_fit - INFO - Using weighting = unweighted
# 2017-02-16 17:04:23,872 - stpipe.SloperPipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full((3, 1024, 1032), 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)

# %% [markdown]
# #### quick check of output

# %%
# set the new level 2A filename
level2A_file = input_basename + '_rate.fits'

# open the level 2A file using astropy fits
with fits.open(level2A_file) as hdulist:

    # print extension table info
    hdulist.info()

    # check the status of each 2A calibration step
    print ""
    print 'Status of 2A calibration steps in output header:'
    stepsCheck = ['S_DQINIT', 'S_SATURA', 'S_IPC', 'S_REFPIX', 'S_RSCD', 'S_LASTFR', 'S_LINEAR', 'S_DARK', 'S_PERSIS', 'S_JUMP', 'S_RAMP']
    for key in stepsCheck:
        print key + ': ' + hdulist[0].header[key]
# Out:
# Filename: det_image_1_MIRIMAGE_F1130Wexp1_rate.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     173   ()
#   1  SCI         ImageHDU         9   (1032, 1024)   float32
#   2  DQ          ImageHDU        10   (1032, 1024)   int32 (rescales to uint32)
#   3  ERR         ImageHDU         8   (1032, 1024)   float32
#   4  ASDF        ImageHDU         7   (4637,)   uint8
#
# Status of 2A calibration steps in output header:
# S_DQINIT: COMPLETE
# S_SATURA: COMPLETE
# S_IPC: COMPLETE
# S_REFPIX: COMPLETE
# S_RSCD: COMPLETE
# S_LASTFR: COMPLETE
# S_LINEAR: COMPLETE
# S_DARK: COMPLETE
# S_PERSIS: SKIPPED
# S_JUMP: COMPLETE
# S_RAMP: COMPLETE

# %% [markdown]
# ### Level 2B pipeline

# %% [markdown]
# #### import the level 2B pipeline class and print description

# %%
from jwst.pipeline import Image2Pipeline
print Image2Pipeline.__doc__
# Out:
#     CalWebbImage2: Processes JWST imaging-mode slope images from
#                    Level-2a to Level-2b.
#
#     Included steps are:
#     assign_wcs, flat_field, and photom.

# %% [markdown]
# The level 2B steps are executed in the order they appear in the description
#
# Note that bkg_subtract requires an association so will not be applied to single files. srctype specifies whether the source is point like or extended. In Build 7, this simply writes the source type keyword without applying an algorithm to make the decision.

# %% [markdown]
# #### run pipeline

# %%
Image2Pipeline.call(level2A_file, output_file='%s_cal.fits' % input_basename)
# Out:
# 2017-02-08 19:58:48,656 - stpipe.Image2Pipeline - INFO - Image2Pipeline instance created.
# 2017-02-08 19:58:48,659 - stpipe.Image2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2017-02-08 19:58:48,661 - stpipe.Image2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2017-02-08 19:58:48,663 - stpipe.Image2Pipeline.photom - INFO - PhotomStep instance created.
# 2017-02-08 19:58:49,890 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2017-02-08 19:58:49,891 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2017-02-08 19:58:49,891 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2017-02-08 19:58:49,892 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0020.asdf'.
# 2017-02-08 19:58:49,893 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for FILTEROFFSET reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_filteroffset_0002.asdf'.
# 2017-02-08 19:58:49,894 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for FORE reference file is 'N/A'.
# 2017-02-08 19:58:49,894 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for FPA reference file is 'N/A'.
# 2017-02-08 19:58:49,895 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2017-02-08 19:58:49,896 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2017-02-08 19:58:49,897 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2017-02-08 19:58:49,897 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for MSA reference file is 'N/A'.
# 2017-02-08 19:58:49,898 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for OTE reference file is 'N/A'.
# 2017-02-08 19:58:49,899 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2017-02-08 19:58:49,900 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2017-02-08 19:58:49,901 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for V2V3 reference file is 'N/A'.
# 2017-02-08 19:58:49,902 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2017-02-08 19:58:50,658 - stpipe.Image2Pipeline.photom - INFO - Prefetch for AREA reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_area_0002.fits'.
# 2017-02-08 19:58:50,659 - stpipe.Image2Pipeline.photom - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits'.
# 2017-02-08 19:58:50,795 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline running with args ('det_image_1_MIRIMAGE_F1130Wexp1_rate.fits',).
# 2017-02-08 19:58:50,796 - stpipe.Image2Pipeline - INFO - Starting calwebb_image2 ...
# 2017-02-08 19:58:51,403 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2017-02-08 19:58:51,404 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2017-02-08 19:58:51,405 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2017-02-08 19:58:51,406 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0020.asdf'.
# 2017-02-08 19:58:51,407 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for FILTEROFFSET reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_filteroffset_0002.asdf'.
# 2017-02-08 19:58:51,408 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for FORE reference file is 'N/A'.
# 2017-02-08 19:58:51,408 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for FPA reference file is 'N/A'.
# 2017-02-08 19:58:51,409 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2017-02-08 19:58:51,410 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2017-02-08 19:58:51,411 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2017-02-08 19:58:51,411 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for MSA reference file is 'N/A'.
# 2017-02-08 19:58:51,412 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for OTE reference file is 'N/A'.
# 2017-02-08 19:58:51,413 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2017-02-08 19:58:51,414 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2017-02-08 19:58:51,415 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for V2V3 reference file is 'N/A'.
# 2017-02-08 19:58:51,415 - stpipe.Image2Pipeline.assign_wcs - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2017-02-08 19:58:51,499 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs running with args ('det_image_1_MIRIMAGE_F1130Wexp1_rate.fits',).
# 2017-02-08 19:58:56,538 - stpipe.Image2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2017-02-08 19:58:56,689 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2017-02-08 19:58:56,863 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field running with args (<jwst.datamodels.image.ImageModel object at 0x23c03e690>,).
# 2017-02-08 19:58:57,676 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-02-08 19:58:57,678 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-02-08 19:58:57,679 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-02-08 19:58:57,694 - stpipe.Image2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-02-08 19:58:58,181 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# 2017-02-08 19:58:58,961 - stpipe.Image2Pipeline.photom - INFO - Prefetch for AREA reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_area_0002.fits'.
# 2017-02-08 19:58:58,962 - stpipe.Image2Pipeline.photom - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits'.
# 2017-02-08 19:58:59,029 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<jwst.datamodels.image.ImageModel object at 0x10d745a10>,).
# 2017-02-08 19:58:59,745 - stpipe.Image2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits
# 2017-02-08 19:59:00,254 - stpipe.Image2Pipeline.photom - INFO - Using area reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_area_0002.fits
# 2017-02-08 19:59:00,518 - stpipe.Image2Pipeline.photom - INFO - Pixel area map written.
# 2017-02-08 19:59:00,519 - stpipe.Image2Pipeline.photom - INFO - Writing PHOTMJSR with value: 2.44947
# 2017-02-08 19:59:00,625 - stpipe.Image2Pipeline.photom - INFO - Step photom done
# 2017-02-08 19:59:00,626 - stpipe.Image2Pipeline - INFO - ... ending calwebb_image2
# 2017-02-08 19:59:00,729 - stpipe.Image2Pipeline - INFO - Saving file /Users/patrickkavanagh/tutorials page/notebooks/IMA_pipeline/det_image_1_MIRIMAGE_F1130Wexp1_cal.fits
# 2017-02-08 19:59:01,221 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline done

# %% [markdown]
# ### check of output

# %% [markdown]
# The level 2B pipeline for the Imager produces a calibrated level 2B file ending in _cal.fits
#
# We can have a look at this output and the calibrated image

# %% [markdown]
# #### fits file extension table and step check

# %%
# set the new level 2B filename
level2B_file = input_basename + '_cal.fits'

# open the level 2B file using astropy fits
with fits.open(level2B_file) as hdulist:

    # print extension table info
    hdulist.info()

    # check the status of each 2B calibration step
    print ""
    print 'Status of 2B calibration steps in output header:'
    stepsCheck = ['S_WCS', 'S_FLAT', 'S_PHOTOM']
    for key in stepsCheck:
        print key + ': ' + hdulist[0].header[key]
# Out:
# Filename: det_image_1_MIRIMAGE_F1130Wexp1_cal.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     259   ()
#   1  SCI         ImageHDU         9   (1032, 1024)   float32
#   2  DQ          ImageHDU        10   (1032, 1024)   int32 (rescales to uint32)
#   3  ERR         ImageHDU         8   (1032, 1024)   float32
#   4  AREA        ImageHDU         8   (1024, 1024)   float32
#   5  ASDF        ImageHDU         7   (16904,)   uint8
#
# Status of 2B calibration steps in output header:
# S_WCS: COMPLETE
# S_FLAT: COMPLETE
# S_PHOTOM: COMPLETE

# %% [markdown]
# #### calibrated image

# %%
from jwst import datamodels
from matplotlib.colors import LogNorm

# open the input image as a jwst data model
with datamodels.open(input_file) as in_dm:
        
    # open the calibrated image as a jwst data model
    with datamodels.open(level2B_file) as im_dm:

        # plot--------------------------------------
        # show the input ramp image and the calibrated
        # slope image.
        # %matplotlib notebook
        fig, axs = plt.subplots(1, 2, figsize=(12, 6))

        # sum the groups in the first integration of the input ramp image and plot
        axs[0].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1.0e4,vmax=1.3e4))
        axs[0].annotate('Input ramp image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[0].set_axis_bgcolor('black')
        axs[1].imshow(im_dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=-3, vmax=30)
        axs[1].annotate('Calibrated slope image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[1].set_axis_bgcolor('black')

        plt.tight_layout()
        plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Level 3 pipeline

# %% [markdown]
# #### import the level 3 pipeline class and print description

# %%
from jwst.pipeline import Image3Pipeline
print Image3Pipeline.__doc__
# Out:
#     Image3Pipeline: Applies level 3 processing to imaging-mode data from
#                     any JWST instrument.
#
#     Included steps are:
#         tweakreg_catalog
#         tweakreg
#         skymatch
#         outlier_detection
#         resample
#         source_catalog

# %% [markdown]
# The level 3 steps are executed in the order they appear in the description
#
# Note that the tweakreg, tweakreg_catalog, skymatch and outlier_detection steps require an association so will be skipped for single files.

# %% [markdown]
# #### run pipeline
#
# ### NOTE THAT THERE IS CURRENTLY A PROBLEM WITH IMAGE3PIPELINE
# At the moment there are issues running the level 2B file through the level 3 pipeline. This has been reported to STScI. This notebook will be updated once this problem has been fixed.

# %%
Image3Pipeline.call(level2B_file)
# Out:
# 2017-02-08 20:02:57,608 - stpipe.Image3Pipeline - INFO - Image3Pipeline instance created.
# 2017-02-08 20:02:57,611 - stpipe.Image3Pipeline.resample - INFO - ResampleStep instance created.
# 2017-02-08 20:02:57,614 - stpipe.Image3Pipeline.tweakreg_catalog - INFO - TweakregCatalogStep instance created.
# 2017-02-08 20:02:57,619 - stpipe.Image3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2017-02-08 20:02:57,622 - stpipe.Image3Pipeline.skymatch - INFO - SkyMatchStep instance created.
# 2017-02-08 20:02:57,625 - stpipe.Image3Pipeline.source_catalog - INFO - SourceCatalogStep instance created.
# 2017-02-08 20:02:57,628 - stpipe.Image3Pipeline.tweakreg - INFO - TweakRegStep instance created.
# 2017-02-08 20:02:59,791 - stpipe.Image3Pipeline.resample - INFO - Prefetch for DRIZPARS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2017-02-08 20:03:01,073 - stpipe.Image3Pipeline.outlier_detection - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2017-02-08 20:03:01,074 - stpipe.Image3Pipeline.outlier_detection - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits'.
# 2017-02-08 20:03:01,867 - stpipe.Image3Pipeline - INFO - Step Image3Pipeline running with args ('det_image_1_MIRIMAGE_F1130Wexp1_cal.fits',).
# 2017-02-08 20:03:01,868 - stpipe.Image3Pipeline - INFO - Starting calwebb_image3 ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-7256a0e283a3> in <module>()
# ----> 1 Image3Pipeline.call(level2B_file)
#
# /Users/patrickkavanagh/anaconda/envs/jwstb7/lib/python2.7/site-packages/jwst-0.7.7-py2.7-macosx-10.7-x86_64.egg/jwst/stpipe/step.pyc in call(cls, *args, **kwargs)
#     434         else:
#     435             instance = cls(**kwargs)
# --> 436         return instance.run(*args)
#     437
#     438     @classmethod
#
# /Users/patrickkavanagh/anaconda/envs/jwstb7/lib/python2.7/site-packages/jwst-0.7.7-py2.7-macosx-10.7-x86_64.egg/jwst/stpipe/step.pyc in run(self, *args)
#     341             else:
#     342                 try:
# --> 343                     result = self.process(*args)
#     344                 except TypeError as e:
#     345                     if "process() takes exactly" in e.message:
#
# /Users/patrickkavanagh/anaconda/envs/jwstb7/lib/python2.7/site-packages/jwst-0.7.7-py2.7-macosx-10.7-x86_64.egg/jwst/pipeline/calwebb_image3.pyc in process(self, input)
#      78         # Setup output file name for subsequent use
#      79         output_file = mk_prodname(self.output_dir,
# ---> 80             input_models.meta.resample.output, 'i2d')
#      81         input_models.meta.resample.output = output_file
#      82
#
# /Users/patrickkavanagh/anaconda/envs/jwstb7/lib/python2.7/site-packages/jwst-0.7.7-py2.7-macosx-10.7-x86_64.egg/jwst/datamodels/properties.pyc in __getattr__(self, attr)
#     187         except KeyError:
#     188             if schema == {}:
# --> 189                 raise AttributeError("No attribute '{0}'".format(attr))
#     190             val = _make_default(attr, schema, self._ctx)
#     191             self._instance[attr] = val
#
# AttributeError: No attribute 'resample'
